# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = "/content/drive/MyDrive/MACROBATT/FINAL_SURVIVOR_DEATH/SVM/DISAM/pretrained_zeroshot-disambiguation-results.csv"
Corpus = pd.read_csv(csv_path ,delimiter=',',encoding='latin-1')
Corpus.head()
# Out:
#           Filename                                               Text  \
# 0  28353604_df.csv  A 69-year-old man became aware of the onset of...
# 1  28559815_df.csv  A 34-year-old woman, 1 week postpartum, presen...
# 2  28538413_df.csv  A 63-year-old male patient without smoking or ...
# 3  28353588_df.csv  A 75-year-old man was referred to our hospital...
# 4  28353596_df.csv  A 47-year-old female patient presented progres...
#
#      ACTUAL PREDICTED
# 0  survivor  survivor
# 1  survivor  survivor
# 2  survivor  survivor
# 3  survivor     death
# 4  survivor  survivor

# %%
Corpus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Filename   200 non-null    object
#  1   Text       200 non-null    object
#  2   ACTUAL     200 non-null    object
#  3   PREDICTED  200 non-null    object
# dtypes: object(4)
# memory usage: 6.4+ KB

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')

# 1. Removing Blank Spaces
Corpus['Text'].dropna(inplace=True)
# 2. Changing all text to lowercase
Corpus['text_original'] = Corpus['Text']
Corpus['Text'] = [entry.lower() for entry in Corpus['Text']]
# 3. Tokenization-In this each entry in the corpus will be broken into set of words
Corpus['Text']= [word_tokenize(entry) for entry in Corpus['Text']]
# 4. Remove Stop words, Non-Numeric and perfoming Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

Corpus.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#           Filename                                               Text  \
# 0  28353604_df.csv  [a, 69-year-old, man, became, aware, of, the, ...
# 1  28559815_df.csv  [a, 34-year-old, woman, ,, 1, week, postpartum...
# 2  28538413_df.csv  [a, 63-year-old, male, patient, without, smoki...
# 3  28353588_df.csv  [a, 75-year-old, man, was, referred, to, our, ...
# 4  28353596_df.csv  [a, 47-year-old, female, patient, presented, p...
#
#      ACTUAL PREDICTED                                      text_original
# 0  survivor  survivor  A 69-year-old man became aware of the onset of...
# 1  survivor  survivor  A 34-year-old woman, 1 week postpartum, presen...
# 2  survivor  survivor  A 63-year-old male patient without smoking or ...
# 3  survivor     death  A 75-year-old man was referred to our hospital...
# 4  survivor  survivor  A 47-year-old female patient presented progres...

# %%
for index,entry in enumerate(Corpus['Text']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    Corpus.loc[index,'text_final'] = str(Final_words)

# %%
Corpus.drop(['Text'], axis=1)
output_path = '/content/drive/MyDrive/MACROBATT/FINAL_SURVIVOR_DEATH/SVM/DISAM/preprocessed_svm.csv'
Corpus.to_csv(output_path, index=False)

# %%
Corpus
# Out:
#             Filename                                               Text  \
# 0    28353604_df.csv  [a, 69-year-old, man, became, aware, of, the, ...
# 1    28559815_df.csv  [a, 34-year-old, woman, ,, 1, week, postpartum...
# 2    28538413_df.csv  [a, 63-year-old, male, patient, without, smoki...
# 3    28353588_df.csv  [a, 75-year-old, man, was, referred, to, our, ...
# 4    28353596_df.csv  [a, 47-year-old, female, patient, presented, p...
# ..               ...                                                ...
# 195  21477357_df.csv  [a, 52-year-old, man, (, body, surface, area, ...
# 196  18258107_df.csv  [here, ,, we, describe, another, case, in, a, ...
# 197  19860007_df.csv  [a, 70-year-old, man, was, referred, to, our, ...
# 198  18236639_df.csv  [a, 30-year-old, female, (, 65, kg, ), underwe...
# 199  19860006_df.csv  [a, 72-year-old, woman, underwent, rf, ablatio...
#
#        ACTUAL PREDICTED                                      text_original  \
# 0    survivor  survivor  A 69-year-old man became aware of the onset of...
# 1    survivor  survivor  A 34-year-old woman, 1 week postpartum, presen...
# 2    survivor  survivor  A 63-year-old male patient without smoking or ...
# 3    survivor     death  A 75-year-old man was referred to our hospital...
# 4    survivor  survivor  A 47-year-old female patient presented progres...
# ..        ...       ...                                                ...
# 195  survivor  survivor  A 52-year-old man (body surface area: 1.3 m2) ...
# 196  survivor  survivor  Here, we describe another case in a 60-year-ol...
# 197  survivor  survivor  A 70-year-old man was referred to our hospital...
# 198  survivor  survivor  A 30-year-old female (65 kg) underwent rhinopl...
# 199  survivor  survivor  A 72-year-old woman underwent RF ablation for ...
#
#                                             text_final
# 0    ['man', 'become', 'aware', 'onset', 'exertiona...
# 1    ['woman', 'week', 'postpartum', 'present', 'de...
# 2    ['male', 'patient', 'without', 'smoking', 'dri...
# 3    ['man', 'refer', 'hospital', 'evaluation', 'dy...
# 4    ['female', 'patient', 'present', 'progressivel...
# ..                                                 ...
# 195  ['man', 'body', 'surface', 'area', 'know', 'di...
# 196  ['describe', 'another', 'case', 'man', 'san', ...
# 197  ['man', 'refer', 'hospital', 'gastric', 'cance...
# 198  ['female', 'kg', 'underwent', 'rhinoplasty', '...
# 199  ['woman', 'underwent', 'rf', 'ablation', 'trea...
#
# [200 rows x 6 columns]

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(Corpus['text_final'],Corpus['ACTUAL'],test_size=0.2)

# %%
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(Corpus['text_final'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

print(Tfidf_vect.vocabulary_)
# Out:
# {'man': 2333, 'become': 376, 'aware': 338, 'onset': 2692, 'exertional': 1450, 'dyspnea': 1268, 'july': 2169, 'history': 1853, 'smoke': 3887, 'year': 4983, 'cigarette': 624, 'per': 2841, 'day': 914, 'parent': 2797, 'brother': 477, 'lung': 2295, 'cancer': 506, 'past': 2809, 'medical': 2384, 'unremarkable': 4692, 'occupational': 2666, 'exposure': 1469, 'due': 1247, 'admit': 78, 'people': 2839, 'hospital': 1871, 'shunde': 3818, 'district': 1181, 'echocardiography': 1284, 'compute': 730, 'tomography': 4463, 'pulmonary': 3235, 'angiography': 190, 'indicate': 2001, 'severe': 3789, 'arterial': 264, 'hypertension': 1907, 'pressure': 3099, 'pap': 2781, 'right': 3580, 'heart': 1784, 'enlarge': 1361, 'ventricle': 4800, 'diameter': 1073, 'show': 3815, 'also': 138, 'thrombus': 4412, 'upper': 4705, 'lobe': 2271, 'artery': 266, 'however': 1877, 'region': 3418, 'affect': 95, 'embolism': 1331, 'consider': 772, 'small': 3885, 'induce': 2005, 'addition': 59, 'connective': 764, 'tissue': 4447, 'disease': 1143, 'drug': 1243, 'use': 4731, 'chemotherapy': 596, 'human': 1880, 'immunodeficiency': 1961, 'virus': 4851, 'test': 4342, 'diagnose': 1067, 'idiopathic': 1942, 'combine': 695, 'treat': 4555, 'warfarin': 4893, 'target': 4288, 'international': 2080, 'normalized': 2619, 'ratio': 3333, 'inr': 2048, 'slidenafil': 3874, 'therapy': 4361, 'twice': 4610, 'patient': 2820, 'relieve': 3450, 'slightly': 3876, 'medication': 2385, 'month': 2492, 'retested': 3536, 'decrease': 937, 'symptom': 4238, 'sign': 3832, 'fail': 1501, 'improve': 1978, 'take': 4277, 'march': 2348, 'go': 1718, 'university': 4688, 'affiliate': 98, 'japan': 2153, 'treatment': 4557, 'catheterization': 553, 'reveal': 3554, 'capillary': 514, 'wedge': 4915, 'cardiac': 526, 'output': 2736, 'ejection': 1306, 'index': 1999, 'vascular': 4776, 'resistance': 3498, 'wood': 4956, 'unit': 4686, 'computed': 731, 'disappear': 1125, 'still': 4036, 'treated': 4556, 'sildenafil': 3837, 'time': 4440, 'sorafenib': 3920, 'oral': 2711, 'anticoagulation': 209, 'daily': 909, 'dose': 1215, 'adjust': 71, 'disappointingly': 1127, 'around': 257, 'september': 3753, 'visit': 4857, 'shanghai': 3799, 'china': 605, 'relief': 3449, 'blood': 427, 'gas': 1659, 'analysis': 176, 'oxygen': 2751, 'saturation': 3656, 'function': 1640, 'mild': 2450, 'obstructive': 2654, 'dysfunction': 1260, 'ventilation': 4797, 'forced': 1610, 'expiratory': 1462, 'volume': 4875, 'prediction': 3068, 'reduction': 3397, 'diffusing': 1100, 'capacity': 512, 'carbon': 519, 'dlco': 1194, 'walk': 4887, 'chest': 598, 'hrct': 1878, 'smooth': 3891, 'thickening': 4372, 'interlobular': 2075, 'septum': 3755, 'diffuse': 1096, 'nodule': 2606, 'enlargement': 1363, 'mediastinal': 2381, 'lymph': 2300, 'node': 2604, 'acute': 52, 'vasodilator': 4784, 'testing': 4345, 'negative': 2566, 'coronary': 832, 'normal': 2615, 'scan': 3664, 'perfusion': 2851, 'defect': 949, 'bronchoalveolar': 471, 'lavage': 2216, 'elevated': 1324, 'macrophage': 2311, 'score': 3693, 'range': 3323, 'suspect': 4209, 'peripheral': 2867, 'occlusive': 2664, 'continuously': 798, 'targeted': 4289, 'continue': 795, 'stop': 4048, 'sometime': 3912, 'recall': 3360, 'exact': 1431, 'date': 913, 'felt': 1528, 'coagulation': 665, 'monitoring': 2489, 'furthermore': 1647, 'discontinue': 1136, 'monitor': 2488, 'prevent': 3107, 'recurrence': 3390, 'relatively': 3443, 'stable': 3989, 'develop': 1057, 'many': 2345, 'episode': 1383, 'edema': 1290, 'january': 2152, 'rush': 3622, 'suddenly': 4141, 'main': 2320, 'rivaroxaban': 3590, 'administer': 74, 'therefore': 4364, 'ill': 1953, 'instead': 2057, 'bind': 402, 'wheelchair': 4925, 'half': 1762, 'transplantation': 4542, 'survival': 4205, 'six': 3860, 'later': 2212, 'undergone': 4657, 'bilateral': 397, 'sequential': 3762, 'allogenic': 128, 'assist': 289, 'membrane': 2400, 'oxygenation': 2753, 'veteran': 4828, 'write': 4972, 'consent': 768, 'histology': 1848, 'explanted': 1465, 'specimen': 3941, 'vein': 4790, 'occlusion': 2663, 'confirm': 754, 'live': 2268, 'well': 4920, 'wi ...

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  95.0

# %%
print(classification_report(Test_Y,predictions_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.95      1.00      0.97        38
#
#     accuracy                           0.95        40
#    macro avg       0.47      0.50      0.49        40
# weighted avg       0.90      0.95      0.93        40
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
